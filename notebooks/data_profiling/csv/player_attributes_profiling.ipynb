# %%
import numpy as np
import pandas as pd
from ydata_profiling import ProfileReport
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('../../data/raw/player_attributes.csv',
               encoding='latin-1')
df
# Out:
#             id  player_fifa_api_id  player_api_id  overall_rating  potential  \
# 0            1              218353         505942            67.0       71.0
# 1            2              218353         505942            67.0       71.0
# 2            3              218353         505942            62.0       66.0
# 3            4              218353         505942            61.0       65.0
# 4            5              218353         505942            61.0       65.0
# ...        ...                 ...            ...             ...        ...
# 183973  183974              102359          39902            83.0       85.0
# 183974  183975              102359          39902            78.0       80.0
# 183975  183976              102359          39902            77.0       80.0
# 183976  183977              102359          39902            78.0       81.0
# 183977  183978              102359          39902            80.0       81.0
#
#        preferred_foot attacking_work_rate defensive_work_rate  crossing  \
# 0               right              medium              medium      49.0
# 1               right              medium              medium      49.0
# 2               right              medium              medium      49.0
# 3               right              medium              medium      48.0
# 4               right              medium              medium      48.0
# ...               ...                 ...                 ...       ...
# 183973          right              medium                 low      84.0
# 183974          right              medium                 low      74.0
# 183975          right              medium                 low      74.0
# 183976          right              medium                 low      74.0
# 183977          right              medium                 low      74.0
#
#         finishing  ...  vision  penalties  marking  standing_tackle  \
# 0            44.0  ...    54.0       48.0     65.0             69.0
# 1            44.0  ...    54.0       48.0     65.0             69.0
# 2            44.0  ...    54.0       48.0     65.0             66.0
# 3            43.0  ...    53.0       47.0     62.0             63.0
# 4            43.0  ...    53.0       47.0     62.0             63.0
# ...           ...  ...     ...        ...      ...              ...
# 183973       77.0  ...    88.0       83.0     22.0             31.0
# 183974       76.0  ...    88.0       70.0     32.0             31.0
# 183975       71.0  ...    88.0       70.0     32.0             31.0
# 183976       64.0  ...    88.0       53.0     28.0             32.0
# 183977       68.0  ...    88.0       53.0     38.0             32.0
#
#         sliding_tackle  gk_diving  gk_handling  gk_kicking  gk_positioning  \
# 0                 69.0        6.0         11.0        10.0             8.0
# 1                 69.0        6.0         11.0        10.0             8.0
# 2                 69.0        6.0         11.0        10.0             8.0
# 3                 66.0        5.0         10.0         9.0             7.0
# 4                 66.0        5.0         10.0         9.0             7.0
# ...                ...        ...          ...         ...             ...
# 183973            30.0        9.0         20.0        84.0            20.0
# 183974            30.0        9.0         20.0        73.0            20.0
# 183975            30.0        9.0         20.0        73.0            20.0
# 183976            30.0        9.0         20.0        73.0            20.0
# 183977            30.0        9.0          9.0        78.0             7.0
#
#         gk_reflexes
# 0               8.0
# 1               8.0
# 2               8.0
# 3               7.0
# 4               7.0
# ...             ...
# 183973         20.0
# 183974         20.0
# 183975         20.0
# 183976         20.0
# 183977         15.0
#
# [183978 rows x 41 columns]

# %%
df.dtypes
# Out:
# id                       int64
# player_fifa_api_id       int64
# player_api_id            int64
# overall_rating         float64
# potential              float64
# preferred_foot          object
# attacking_work_rate     object
# defensive_work_rate     object
# crossing               float64
# finishing              float64
# heading_accuracy       float64
# short_passing          float64
# volleys                float64
# dribbling              float64
# curve                  float64
# free_kick_accuracy     float64
# long_passing           float64
# ball_control           float64
# acceleration           float64
# sprint_speed           float64
# agility                float64
# reactions              float64
# balance                float64
# shot_power             float64
# jumping                float64
# stamina                float64
# strength               float64
# long_shots             float64
# aggression             float64
# interceptions          float64
# positioning            float64
# vision                 float64
# penalties              float64
# marking                float64
# standing_tackle        float64
# sliding_tackle         float64
# gk_diving              float64
# gk_handling            float64
# gk_kicking             float64
# gk_positioning         float64
# gk_reflexes            float64
# dtype: object

# %%
pd.set_option('display.float_format',lambda x: '%.2f' % x)

# %%
df.describe()
# Out:
#              id  player_fifa_api_id  player_api_id  overall_rating  potential  \
# count 183978.00           183978.00      183978.00       183142.00  183142.00
# mean   91989.50           165671.52      135900.62           68.60      73.46
# std    53110.02            53851.09      136927.84            7.04       6.59
# min        1.00                2.00        2625.00           33.00      39.00
# 25%    45995.25           155798.00       34763.00           64.00      69.00
# 50%    91989.50           183488.00       77741.00           69.00      74.00
# 75%   137983.75           199848.00      191080.00           73.00      78.00
# max   183978.00           234141.00      750584.00           94.00      97.00
#
#        crossing  finishing  heading_accuracy  short_passing   volleys  ...  \
# count 183142.00  183142.00         183142.00      183142.00 181265.00  ...
# mean      55.09      49.92             57.27          62.43     49.47  ...
# std       17.24      19.04             16.49          14.19     18.26  ...
# min        1.00       1.00              1.00           3.00      1.00  ...
# 25%       45.00      34.00             49.00          57.00     35.00  ...
# 50%       59.00      53.00             60.00          65.00     52.00  ...
# 75%       68.00      65.00             68.00          72.00     64.00  ...
# max       95.00      97.00             98.00          97.00     93.00  ...
#
#          vision  penalties   marking  standing_tackle  sliding_tackle  \
# count 181265.00  183142.00 183142.00        183142.00       181265.00
# mean      57.87      55.00     46.77            50.35           48.00
# std       15.14      15.55     21.23            21.48           21.60
# min        1.00       2.00      1.00             1.00            2.00
# 25%       49.00      45.00     25.00            29.00           25.00
# 50%       60.00      57.00     50.00            56.00           53.00
# 75%       69.00      67.00     66.00            69.00           67.00
# max       97.00      96.00     96.00            95.00           95.00
#
#        gk_diving  gk_handling  gk_kicking  gk_positioning  gk_reflexes
# count  183142.00    183142.00   183142.00       183142.00    183142.00
# mean       14.70        16.06       21.00           16.13        16.44
# std        16.87        15.87       21.45           16.10        17.20
# min         1.00         1.00        1.00            1.00         1.00
# 25%         7.00         8.00        8.00            8.00         8.00
# 50%        10.00        11.00       12.00           11.00        11.00
# 75%        13.00        15.00       15.00           15.00        15.00
# max        94.00        93.00       97.00           96.00        96.00
#
# [8 rows x 38 columns]

# %%
simple_profile = df.describe(include='all')
simple_profile
# Out:
#               id  player_fifa_api_id  player_api_id  overall_rating  \
# count  183978.00           183978.00      183978.00       183142.00
# unique       NaN                 NaN            NaN             NaN
# top          NaN                 NaN            NaN             NaN
# freq         NaN                 NaN            NaN             NaN
# mean    91989.50           165671.52      135900.62           68.60
# std     53110.02            53851.09      136927.84            7.04
# min         1.00                2.00        2625.00           33.00
# 25%     45995.25           155798.00       34763.00           64.00
# 50%     91989.50           183488.00       77741.00           69.00
# 75%    137983.75           199848.00      191080.00           73.00
# max    183978.00           234141.00      750584.00           94.00
#
#         potential preferred_foot attacking_work_rate defensive_work_rate  \
# count   183142.00         183142              177109              183142
# unique        NaN              2                   7                  19
# top           NaN          right              medium              medium
# freq          NaN         138409              125070              130846
# mean        73.46            NaN                 NaN                 NaN
# std          6.59            NaN                 NaN                 NaN
# min         39.00            NaN                 NaN                 NaN
# 25%         69.00            NaN                 NaN                 NaN
# 50%         74.00            NaN                 NaN                 NaN
# 75%         78.00            NaN                 NaN                 NaN
# max         97.00            NaN                 NaN                 NaN
#
#         crossing  finishing  ...    vision  penalties   marking  \
# count  183142.00  183142.00  ... 181265.00  183142.00 183142.00
# unique       NaN        NaN  ...       NaN        NaN       NaN
# top          NaN        NaN  ...       NaN        NaN       NaN
# freq         NaN        NaN  ...       NaN        NaN       NaN
# mean       55.09      49.92  ...     57.87      55.00     46.77
# std        17.24      19.04  ...     15.14      15.55     21.23
# min         1.00       1.00  ...      1.00       2.00      1.00
# 25%        45.00      34.00  ...     49.00      45.00     25.00
# 50%        59.00      53.00  ...     60.00      57.00     50.00
# 75%        68.00      65.00  ...     69.00      67.00     66.00
# max        95.00      97.00  ...     97.00      96.00     96.00
#
#         standing_tackle  sliding_tackle  gk_diving  gk_handling  gk_kicking  \
# count         183142.00       181265.00  183142.00    183142.00   183142.00
# unique              NaN             NaN        NaN          NaN         NaN
# top                 NaN             NaN        NaN          NaN         NaN
# freq                NaN             NaN        NaN          NaN         NaN
# mean              50.35           48.00      14.70        16.06       21.00
# std               21.48           21.60      16.87        15.87       21.45
# min                1.00            2.00       1.00         1.00        1.00
# 25%               29.00           25.00       7.00         8.00        8.00
# 50%               56.00           53.00      10.00        11.00       12.00
# 75%               69.00           67.00      13.00        15.00       15.00
# max               95.00           95.00      94.00        93.00       97.00
#
#         gk_positioning  gk_reflexes
# count        183142.00    183142.00
# unique             NaN          NaN
# top                NaN          NaN
# freq               NaN          NaN
# mean             16.13        16.44
# std              16.10        17.20
# min               1.00         1.00
# 25%               8.00         8.00
# 50%              11.00        11.00
# 75%              15.00        15.00
# max              96.00        96.00
#
# [11 rows x 41 columns]

# %%
profile = ProfileReport(df, title="Export Data Profiling Report")

# %%
profile.to_widgets()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…

# %%
def get_basic_profile(dataframe):
    quantile_range = 0.5
    results = {}
    
    for column in dataframe.columns:
        count = df[column].count()
        nans = df[column].isna().sum()
        min = df[column].min()
        max = df[column].max()
        median = df[column].median()
        std = df[column].std()
        kurt = df[column].kurt()
        skew = df[column].skew()
        quant = df[column].quantile(q=quantile_range)
        
        results[column] = {'count': count,
                            'count_na': nans,
                            'min':min,
                            'max':max,
                            'median':median,
                            'std':std,
                            'kurt':kurt,
                            'skew':skew,
                            'quant {quantile_range}':quant}
 
    return results

# %%
num_columns = df.select_dtypes(include=['int64','float64'])
basic_profile = get_basic_profile(num_columns)
basic_profile
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 num_columns = df.select_dtypes(include=['int64','float64'])
# ----> 2 basic_profile = get_basic_profile(num_columns)
#       3 basic_profile
#
# NameError: name 'get_basic_profile' is not defined

# %%
# square root choice
bins = int(np.ceil(np.sqrt(len(num_columns['VALUE USD']))))
 
fig, ax = plt.subplots(1, 1, figsize=(14,8))
ax.hist(num_columns['VALUE USD'], bins)
 
ax.ticklabel_format(useOffset=False, style='plain')
ax.set_xlabel('Value USD')
ax.set_ylabel('Count')
ax.set_title(r'Histogram of exports in USD')
# plt.savefig("mygraph.jpg")
# Out:
# Text(0.5, 1.0, 'Histogram of exports in USD')
