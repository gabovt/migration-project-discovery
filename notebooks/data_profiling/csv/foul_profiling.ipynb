# %%
import numpy as np
import pandas as pd
from ydata_profiling import ProfileReport
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('../../data/raw/foulcommit.csv',
               encoding='latin-1')
df
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_4600\2819093827.py:1: DtypeWarning: Columns (9,10,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../../data/raw/foulcommit.csv',
#         match_id         id  subtype  event_incident_typefk  elapsed  \
# 0         489042   378824.0      NaN                   37.0      1.0
# 1         489042   378826.0      NaN                   37.0      2.0
# 2         489042   378830.0      NaN                   37.0      3.0
# 3         489042   378841.0      NaN                   37.0      5.0
# 4         489042   378894.0  pushing                  320.0     10.0
# ...          ...        ...      ...                    ...      ...
# 432881   2030171        NaN      NaN                    NaN      NaN
# 432882   2030171        NaN      NaN                    NaN      NaN
# 432883   2030171  4941145.0  penalty                    4.0     90.0
# 432884   2030171        NaN      NaN                    NaN      NaN
# 432885   2030171        NaN      NaN                    NaN      NaN
#
#         elapsed_plus  del  coordinates  injury_time venue card_type   player1  \
# 0                NaN  NaN          NaN          NaN   NaN       NaN   25518.0
# 1                NaN  NaN          NaN          NaN   NaN       NaN   30929.0
# 2                NaN  NaN          NaN          NaN   NaN       NaN   29581.0
# 3                NaN  NaN          NaN          NaN   NaN       NaN   30373.0
# 4                NaN  NaN          NaN          NaN   NaN       NaN   29581.0
# ...              ...  ...          ...          ...   ...       ...       ...
# 432881           NaN  NaN          NaN          NaN   NaN       NaN       NaN
# 432882           NaN  NaN          NaN          NaN   NaN       NaN       NaN
# 432883           3.0  NaN       2864.0          NaN   NaN       NaN  183449.0
# 432884           NaN  NaN          NaN          NaN   NaN       NaN       NaN
# 432885           NaN  NaN          NaN          NaN   NaN       NaN       NaN
#
#         player2     team
# 0       32569.0  10261.0
# 1       24157.0  10261.0
# 2       24148.0  10261.0
# 3       40565.0  10260.0
# 4       30829.0  10261.0
# ...         ...      ...
# 432881      NaN      NaN
# 432882      NaN      NaN
# 432883      NaN   8370.0
# 432884      NaN      NaN
# 432885      NaN      NaN
#
# [432886 rows x 14 columns]

# %%
df.dtypes
# Out:
# match_id                   int64
# id                       float64
# subtype                   object
# event_incident_typefk    float64
# elapsed                  float64
# elapsed_plus             float64
# del                      float64
# coordinates              float64
# injury_time              float64
# venue                     object
# card_type                 object
# player1                   object
# player2                  float64
# team                     float64
# dtype: object

# %%
pd.set_option('display.float_format',lambda x: '%.2f' % x)

# %%
df.describe()
# Out:
#         match_id         id  event_incident_typefk   elapsed  elapsed_plus  \
# count  432886.00  219234.00              219234.00 219234.00      13132.00
# mean  1623209.07 3002935.13                 223.55     47.60          2.38
# std    483912.76 1750487.08                 280.22     26.56          1.37
# min    489042.00  375531.00                   3.00      0.00          1.00
# 25%   1474738.00 1298250.25                  37.00     25.00          1.00
# 50%   1778261.00 3281145.50                  37.00     47.00          2.00
# 75%   1989947.00 4695408.25                 320.00     71.00          3.00
# max   2118418.00 5623577.00                 730.00     90.00         17.00
#
#          del  coordinates  injury_time   player2      team
# count 409.00    106826.00         2.00 190897.00 218824.00
# mean    1.00      2208.11         2.00 112546.72   9680.52
# std     0.00      1356.54         1.41 125941.71  10671.32
# min     1.00        14.00         1.00   2625.00   1601.00
# 25%     1.00       940.00         1.50  30940.00   8533.00
# 50%     1.00      2153.00         2.00  41365.00   8667.00
# 75%     1.00      3433.00         2.50 165583.00   9876.00
# max     1.00      4567.00         3.00 748432.00 208931.00

# %%
simple_profile = df.describe(include='all')
simple_profile
# Out:
#          match_id         id subtype  event_incident_typefk   elapsed  \
# count   432886.00  219234.00  116380              219234.00 219234.00
# unique        NaN        NaN      13                    NaN       NaN
# top           NaN        NaN    trip                    NaN       NaN
# freq          NaN        NaN   30246                    NaN       NaN
# mean   1623209.07 3002935.13     NaN                 223.55     47.60
# std     483912.76 1750487.08     NaN                 280.22     26.56
# min     489042.00  375531.00     NaN                   3.00      0.00
# 25%    1474738.00 1298250.25     NaN                  37.00     25.00
# 50%    1778261.00 3281145.50     NaN                  37.00     47.00
# 75%    1989947.00 4695408.25     NaN                 320.00     71.00
# max    2118418.00 5623577.00     NaN                 730.00     90.00
#
#         elapsed_plus    del  coordinates  injury_time          venue  \
# count       13132.00 409.00    106826.00         2.00              2
# unique           NaN    NaN          NaN          NaN              2
# top              NaN    NaN          NaN          NaN  Borussia-Park
# freq             NaN    NaN          NaN          NaN              1
# mean            2.38   1.00      2208.11         2.00            NaN
# std             1.37   0.00      1356.54         1.41            NaN
# min             1.00   1.00        14.00         1.00            NaN
# 25%             1.00   1.00       940.00         1.50            NaN
# 50%             2.00   1.00      2153.00         2.00            NaN
# 75%             3.00   1.00      3433.00         2.50            NaN
# max            17.00   1.00      4567.00         3.00            NaN
#
#        card_type   player1   player2      team
# count         14 211406.00 190897.00 218824.00
# unique         2   6573.00       NaN       NaN
# top            y  39618.00       NaN       NaN
# freq          13    497.00       NaN       NaN
# mean         NaN       NaN 112546.72   9680.52
# std          NaN       NaN 125941.71  10671.32
# min          NaN       NaN   2625.00   1601.00
# 25%          NaN       NaN  30940.00   8533.00
# 50%          NaN       NaN  41365.00   8667.00
# 75%          NaN       NaN 165583.00   9876.00
# max          NaN       NaN 748432.00 208931.00

# %%
profile = ProfileReport(df, title="Export Data Profiling Report")

# %%
profile.to_widgets()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…

# %%
def get_basic_profile(dataframe):
    quantile_range = 0.5
    results = {}
    
    for column in dataframe.columns:
        count = df[column].count()
        nans = df[column].isna().sum()
        min = df[column].min()
        max = df[column].max()
        median = df[column].median()
        std = df[column].std()
        kurt = df[column].kurt()
        skew = df[column].skew()
        quant = df[column].quantile(q=quantile_range)
        
        results[column] = {'count': count,
                            'count_na': nans,
                            'min':min,
                            'max':max,
                            'median':median,
                            'std':std,
                            'kurt':kurt,
                            'skew':skew,
                            'quant {quantile_range}':quant}
 
    return results

# %%
num_columns = df.select_dtypes(include=['int64','float64'])
basic_profile = get_basic_profile(num_columns)
basic_profile
# Out:
# {'match_id': {'count': 432886,
#   'count_na': 0,
#   'min': 489042,
#   'max': 2118418,
#   'median': 1778261.0,
#   'std': 483912.7608579927,
#   'kurt': -0.11838406645271293,
#   'skew': -1.15090102677934,
#   'quant {quantile_range}': 1778261.0},
#  'id': {'count': 219234,
#   'count_na': 213652,
#   'min': 375531.0,
#   'max': 5623577.0,
#   'median': 3281145.5,
#   'std': 1750487.0819368057,
#   'kurt': -1.571581043925132,
#   'skew': -0.03491483931596429,
#   'quant {quantile_range}': 3281145.5},
#  'event_incident_typefk': {'count': 219234,
#   'count_na': 213652,
#   'min': 3.0,
#   'max': 730.0,
#   'median': 37.0,
#   'std': 280.21507936963724,
#   'kurt': -0.7382840627777401,
#   'skew': 0.9975680802701651,
#   'quant {quantile_range}': 37.0},
#  'elapsed': {'count': 219234,
#   'count_na': 213652,
#   'min': 0.0,
#   'max': 90.0,
#   'median': 47.0,
#   'std': 26.559477808542564,
#   'kurt': -1.1753866008323952,
#   'skew': -0.0054108382601532725,
#   'quant {quantile_range}': 47.0},
#  'elapsed_plus': {'count': 13132,
#   'count_na': 419754,
#   'min': 1.0,
#   'max': 17.0,
#   'median': 2.0,
#   'std': 1.3732269422066306,
#   'kurt': 3.9505638067770312,
#   'skew': 1.3049176546036336,
#   'quant {quantile_range}': 2.0},
#  'del': {'count': 409,
#   'count_na': 432477,
#   'min': 1.0,
#   'max': 1.0,
#   'median': 1.0,
#   'std': 0.0,
#   'kurt': 0,
#   'skew': 0,
#   'quant {quantile_range}': 1.0},
#  'coordinates': {'count': 106826,
#   'count_na': 326060,
#   'min': 14.0,
#   'max': 4567.0,
#   'median': 2153.0,
#   'std': 1356.5424820130575,
#   'kurt': -1.341400397066498,
#   'skew': 0.05781566714873727,
#   'quant {quantile_range}': 2153.0},
#  'injury_time': {'count': 2,
#   'count_na': 432884,
#   'min': 1.0,
#   'max': 3.0,
#   'median': 2.0,
#   'std': 1.4142135623730951,
#   'kurt': nan,
#   'skew': nan,
#   'quant {quantile_range}': 2.0},
#  'player2': {'count': 190897,
#   'count_na': 241989,
#   'min': 2625.0,
#   'max': 748432.0,
#   'median': 41365.0,
#   'std': 125941.71065119984,
#   'kurt': 3.6419667261371735,
#   'skew': 1.925608983385233,
#   'quant {quantile_range}': 41365.0},
#  'team': {'count': 218824,
#   'count_na': 214062,
#   'min': 1601.0,
#   'max': 208931.0,
#   'median': 8667.0,
#   'std': 10671.315774414834,
#   'kurt': 342.4899960480412,
#   'skew': 18.50163108031333,
#   'quant {quantile_range}': 8667.0}}

# %%
# square root choice
bins = int(np.ceil(np.sqrt(len(num_columns['injury_time']))))
 
fig, ax = plt.subplots(1, 1, figsize=(14,8))
ax.hist(num_columns['injury_time'], bins)
 
ax.ticklabel_format(useOffset=False, style='plain')
ax.set_xlabel('Value USD')
ax.set_ylabel('Count')
ax.set_title(r'Histogram of exports in USD')
# plt.savefig("mygraph.jpg")
# Out:
# Text(0.5, 1.0, 'Histogram of exports in USD')
