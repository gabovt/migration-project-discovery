# %%
import numpy as np
import pandas as pd
from ydata_profiling import ProfileReport
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('../../data/raw/team_attributes.csv',
               encoding='latin-1')
df
# Out:
#         id  team_fifa_api_id  team_api_id  buildUpPlaySpeed  \
# 0        1               434         9930                60
# 1        2               434         9930                52
# 2        3               434         9930                47
# 3        4                77         8485                70
# 4        5                77         8485                47
# ...    ...               ...          ...               ...
# 1453  1454             15005        10000                52
# 1454  1455             15005        10000                54
# 1455  1456             15005        10000                54
# 1456  1457             15005        10000                54
# 1457  1458             15005        10000                54
#
#      buildUpPlaySpeedClass  buildUpPlayDribbling buildUpPlayDribblingClass  \
# 0                 Balanced                   NaN                    Little
# 1                 Balanced                  48.0                    Normal
# 2                 Balanced                  41.0                    Normal
# 3                     Fast                   NaN                    Little
# 4                 Balanced                   NaN                    Little
# ...                    ...                   ...                       ...
# 1453              Balanced                   NaN                    Little
# 1454              Balanced                   NaN                    Little
# 1455              Balanced                   NaN                    Little
# 1456              Balanced                  42.0                    Normal
# 1457              Balanced                  42.0                    Normal
#
#       buildUpPlayPassing buildUpPlayPassingClass buildUpPlayPositioningClass  \
# 0                     50                   Mixed                   Organised
# 1                     56                   Mixed                   Organised
# 2                     54                   Mixed                   Organised
# 3                     70                    Long                   Organised
# 4                     52                   Mixed                   Organised
# ...                  ...                     ...                         ...
# 1453                  52                   Mixed                   Organised
# 1454                  51                   Mixed                   Organised
# 1455                  51                   Mixed                   Organised
# 1456                  51                   Mixed                   Organised
# 1457                  51                   Mixed                   Organised
#
#       ...  chanceCreationShooting chanceCreationShootingClass  \
# 0     ...                      55                      Normal
# 1     ...                      64                      Normal
# 2     ...                      64                      Normal
# 3     ...                      70                        Lots
# 4     ...                      52                      Normal
# ...   ...                     ...                         ...
# 1453  ...                      53                      Normal
# 1454  ...                      50                      Normal
# 1455  ...                      32                      Little
# 1456  ...                      32                      Little
# 1457  ...                      32                      Little
#
#       chanceCreationPositioningClass defencePressure  defencePressureClass  \
# 0                          Organised              50                Medium
# 1                          Organised              47                Medium
# 2                          Organised              47                Medium
# 3                          Organised              60                Medium
# 4                          Organised              47                Medium
# ...                              ...             ...                   ...
# 1453                       Organised              46                Medium
# 1454                       Organised              44                Medium
# 1455                       Organised              44                Medium
# 1456                       Organised              44                Medium
# 1457                       Organised              44                Medium
#
#      defenceAggression defenceAggressionClass  defenceTeamWidth  \
# 0                   55                  Press                45
# 1                   44                  Press                54
# 2                   44                  Press                54
# 3                   70                 Double                70
# 4                   47                  Press                52
# ...                ...                    ...               ...
# 1453                48                  Press                53
# 1454                55                  Press                53
# 1455                58                  Press                37
# 1456                58                  Press                37
# 1457                58                  Press                37
#
#      defenceTeamWidthClass  defenceDefenderLineClass
# 0                   Normal                     Cover
# 1                   Normal                     Cover
# 2                   Normal                     Cover
# 3                     Wide                     Cover
# 4                   Normal                     Cover
# ...                    ...                       ...
# 1453                Normal                     Cover
# 1454                Normal                     Cover
# 1455                Normal                     Cover
# 1456                Normal                     Cover
# 1457                Normal                     Cover
#
# [1458 rows x 24 columns]

# %%
df.dtypes
# Out:
# id                                  int64
# team_fifa_api_id                    int64
# team_api_id                         int64
# buildUpPlaySpeed                    int64
# buildUpPlaySpeedClass              object
# buildUpPlayDribbling              float64
# buildUpPlayDribblingClass          object
# buildUpPlayPassing                  int64
# buildUpPlayPassingClass            object
# buildUpPlayPositioningClass        object
# chanceCreationPassing               int64
# chanceCreationPassingClass         object
# chanceCreationCrossing              int64
# chanceCreationCrossingClass        object
# chanceCreationShooting              int64
# chanceCreationShootingClass        object
# chanceCreationPositioningClass     object
# defencePressure                     int64
# defencePressureClass               object
# defenceAggression                   int64
# defenceAggressionClass             object
# defenceTeamWidth                    int64
# defenceTeamWidthClass              object
# defenceDefenderLineClass           object
# dtype: object

# %%
pd.set_option('display.float_format',lambda x: '%.2f' % x)

# %%
df.describe()
# Out:
#            id  team_fifa_api_id  team_api_id  buildUpPlaySpeed  \
# count 1458.00           1458.00      1458.00           1458.00
# mean   729.50          17706.98      9995.73             52.46
# std    421.03          39179.86     13264.87             11.55
# min      1.00              1.00      1601.00             20.00
# 25%    365.25            110.00      8457.75             45.00
# 50%    729.50            485.00      8674.00             52.00
# 75%   1093.75           1900.00      9904.00             62.00
# max   1458.00         112513.00    274581.00             80.00
#
#        buildUpPlayDribbling  buildUpPlayPassing  chanceCreationPassing  \
# count                489.00             1458.00                1458.00
# mean                  48.61               48.49                  52.17
# std                    9.68               10.90                  10.36
# min                   24.00               20.00                  21.00
# 25%                   42.00               40.00                  46.00
# 50%                   49.00               50.00                  52.00
# 75%                   55.00               55.00                  59.00
# max                   77.00               80.00                  80.00
#
#        chanceCreationCrossing  chanceCreationShooting  defencePressure  \
# count                 1458.00                 1458.00          1458.00
# mean                    53.73                   53.97            46.02
# std                     11.09                   10.33            10.23
# min                     20.00                   22.00            23.00
# 25%                     47.00                   48.00            39.00
# 50%                     53.00                   53.00            45.00
# 75%                     62.00                   61.00            51.00
# max                     80.00                   80.00            72.00
#
#        defenceAggression  defenceTeamWidth
# count            1458.00           1458.00
# mean               49.25             52.19
# std                 9.74              9.57
# min                24.00             29.00
# 25%                44.00             47.00
# 50%                48.00             52.00
# 75%                55.00             58.00
# max                72.00             73.00

# %%
simple_profile = df.describe(include='all')
simple_profile
# Out:
#             id  team_fifa_api_id  team_api_id  buildUpPlaySpeed  \
# count  1458.00           1458.00      1458.00           1458.00
# unique     NaN               NaN          NaN               NaN
# top        NaN               NaN          NaN               NaN
# freq       NaN               NaN          NaN               NaN
# mean    729.50          17706.98      9995.73             52.46
# std     421.03          39179.86     13264.87             11.55
# min       1.00              1.00      1601.00             20.00
# 25%     365.25            110.00      8457.75             45.00
# 50%     729.50            485.00      8674.00             52.00
# 75%    1093.75           1900.00      9904.00             62.00
# max    1458.00         112513.00    274581.00             80.00
#
#        buildUpPlaySpeedClass  buildUpPlayDribbling buildUpPlayDribblingClass  \
# count                   1458                489.00                      1458
# unique                     3                   NaN                         3
# top                 Balanced                   NaN                    Little
# freq                    1184                   NaN                      1004
# mean                     NaN                 48.61                       NaN
# std                      NaN                  9.68                       NaN
# min                      NaN                 24.00                       NaN
# 25%                      NaN                 42.00                       NaN
# 50%                      NaN                 49.00                       NaN
# 75%                      NaN                 55.00                       NaN
# max                      NaN                 77.00                       NaN
#
#         buildUpPlayPassing buildUpPlayPassingClass  \
# count              1458.00                    1458
# unique                 NaN                       3
# top                    NaN                   Mixed
# freq                   NaN                    1236
# mean                 48.49                     NaN
# std                  10.90                     NaN
# min                  20.00                     NaN
# 25%                  40.00                     NaN
# 50%                  50.00                     NaN
# 75%                  55.00                     NaN
# max                  80.00                     NaN
#
#        buildUpPlayPositioningClass  ...  chanceCreationShooting  \
# count                         1458  ...                 1458.00
# unique                           2  ...                     NaN
# top                      Organised  ...                     NaN
# freq                          1386  ...                     NaN
# mean                           NaN  ...                   53.97
# std                            NaN  ...                   10.33
# min                            NaN  ...                   22.00
# 25%                            NaN  ...                   48.00
# 50%                            NaN  ...                   53.00
# 75%                            NaN  ...                   61.00
# max                            NaN  ...                   80.00
#
#        chanceCreationShootingClass  chanceCreationPositioningClass  \
# count                         1458                            1458
# unique                           3                               2
# top                         Normal                       Organised
# freq                          1224                            1309
# mean                           NaN                             NaN
# std                            NaN                             NaN
# min                            NaN                             NaN
# 25%                            NaN                             NaN
# 50%                            NaN                             NaN
# 75%                            NaN                             NaN
# max                            NaN                             NaN
#
#        defencePressure  defencePressureClass defenceAggression  \
# count          1458.00                  1458           1458.00
# unique             NaN                     3               NaN
# top                NaN                Medium               NaN
# freq               NaN                  1243               NaN
# mean             46.02                   NaN             49.25
# std              10.23                   NaN              9.74
# min              23.00                   NaN             24.00
# 25%              39.00                   NaN             44.00
# 50%              45.00                   NaN             48.00
# 75%              51.00                   NaN             55.00
# max              72.00                   NaN             72.00
#
#        defenceAggressionClass  defenceTeamWidth defenceTeamWidthClass  \
# count                    1458           1458.00                  1458
# unique                      3               NaN                     3
# top                     Press               NaN                Normal
# freq                     1274               NaN                  1286
# mean                      NaN             52.19                   NaN
# std                       NaN              9.57                   NaN
# min                       NaN             29.00                   NaN
# 25%                       NaN             47.00                   NaN
# 50%                       NaN             52.00                   NaN
# 75%                       NaN             58.00                   NaN
# max                       NaN             73.00                   NaN
#
#         defenceDefenderLineClass
# count                       1458
# unique                         2
# top                        Cover
# freq                        1362
# mean                         NaN
# std                          NaN
# min                          NaN
# 25%                          NaN
# 50%                          NaN
# 75%                          NaN
# max                          NaN
#
# [11 rows x 24 columns]

# %%
profile = ProfileReport(df, title="Export Data Profiling Report")

# %%
profile.to_widgets()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…

# %%
def get_basic_profile(dataframe):
    quantile_range = 0.5
    results = {}
    
    for column in dataframe.columns:
        count = df[column].count()
        nans = df[column].isna().sum()
        min = df[column].min()
        max = df[column].max()
        median = df[column].median()
        std = df[column].std()
        kurt = df[column].kurt()
        skew = df[column].skew()
        quant = df[column].quantile(q=quantile_range)
        
        results[column] = {'count': count,
                            'count_na': nans,
                            'min':min,
                            'max':max,
                            'median':median,
                            'std':std,
                            'kurt':kurt,
                            'skew':skew,
                            'quant {quantile_range}':quant}
 
    return results

# %%
num_columns = df.select_dtypes(include=['int64','float64'])
basic_profile = get_basic_profile(num_columns)
basic_profile
# Out:
# {'id': {'count': 1458,
#   'count_na': 0,
#   'min': 1,
#   'max': 1458,
#   'median': 729.5,
#   'std': 421.03265906577843,
#   'kurt': -1.2000000000000004,
#   'skew': 0.0,
#   'quant {quantile_range}': 729.5},
#  'team_fifa_api_id': {'count': 1458,
#   'count_na': 0,
#   'min': 1,
#   'max': 112513,
#   'median': 485.0,
#   'std': 39179.85773916112,
#   'kurt': 1.64630086694218,
#   'skew': 1.9031017439343585,
#   'quant {quantile_range}': 485.0},
#  'team_api_id': {'count': 1458,
#   'count_na': 0,
#   'min': 1601,
#   'max': 274581,
#   'median': 8674.0,
#   'std': 13264.869899803774,
#   'kurt': 209.99951641987207,
#   'skew': 13.705238528815613,
#   'quant {quantile_range}': 8674.0},
#  'buildUpPlaySpeed': {'count': 1458,
#   'count_na': 0,
#   'min': 20,
#   'max': 80,
#   'median': 52.0,
#   'std': 11.545868812862299,
#   'kurt': -0.559846074897127,
#   'skew': -0.2678557148534108,
#   'quant {quantile_range}': 52.0},
#  'buildUpPlayDribbling': {'count': 489,
#   'count_na': 969,
#   'min': 24.0,
#   'max': 77.0,
#   'median': 49.0,
#   'std': 9.678289619180166,
#   'kurt': -0.1378523441033197,
#   'skew': 0.004463948622159408,
#   'quant {quantile_range}': 49.0},
#  'buildUpPlayPassing': {'count': 1458,
#   'count_na': 0,
#   'min': 20,
#   'max': 80,
#   'median': 50.0,
#   'std': 10.896101497525972,
#   'kurt': -0.43447754604804345,
#   'skew': 0.11935438022984515,
#   'quant {quantile_range}': 50.0},
#  'chanceCreationPassing': {'count': 1458,
#   'count_na': 0,
#   'min': 21,
#   'max': 80,
#   'median': 52.0,
#   'std': 10.360792864140873,
#   'kurt': -0.41402534131808544,
#   'skew': -0.034482897227308254,
#   'quant {quantile_range}': 52.0},
#  'chanceCreationCrossing': {'count': 1458,
#   'count_na': 0,
#   'min': 20,
#   'max': 80,
#   'median': 53.0,
#   'std': 11.086796247225278,
#   'kurt': -0.49634090900790717,
#   'skew': -0.20466590412355518,
#   'quant {quantile_range}': 53.0},
#  'chanceCreationShooting': {'count': 1458,
#   'count_na': 0,
#   'min': 22,
#   'max': 80,
#   'median': 53.0,
#   'std': 10.32756608381605,
#   'kurt': -0.22364153194450287,
#   'skew': -0.1747954205017245,
#   'quant {quantile_range}': 53.0},
#  'defencePressure': {'count': 1458,
#   'count_na': 0,
#   'min': 23,
#   'max': 72,
#   'median': 45.0,
#   'std': 10.227225274184367,
#   'kurt': -0.1918780320178155,
#   'skew': 0.3424379722376358,
#   'quant {quantile_range}': 45.0},
#  'defenceAggression': {'count': 1458,
#   'count_na': 0,
#   'min': 24,
#   'max': 72,
#   'median': 48.0,
#   'std': 9.738027809869905,
#   'kurt': -0.0988984557093362,
#   'skew': 0.21880883167535228,
#   'quant {quantile_range}': 48.0},
#  'defenceTeamWidth': {'count': 1458,
#   'count_na': 0,
#   'min': 29,
#   'max': 73,
#   'median': 52.0,
#   'std': 9.574711779371537,
#   'kurt': -0.1378917349788673,
#   'skew': -0.20736792342413612,
#   'quant {quantile_range}': 52.0}}

# %%
# square root choice
bins = int(np.ceil(np.sqrt(len(num_columns['overall']))))
 
fig, ax = plt.subplots(1, 1, figsize=(14,8))
ax.hist(num_columns['player1'], bins)
 
ax.ticklabel_format(useOffset=False, style='plain')
ax.set_xlabel('player')
ax.set_ylabel('Count')
ax.set_title(r'Histogram of shotoff per player')
# plt.savefig("mygraph.jpg")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\gabri\.conda\envs\migrations\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File c:\Users\gabri\.conda\envs\migrations\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Users\gabri\.conda\envs\migrations\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'player1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 2
#       1 # square root choice
# ----> 2 bins = int(np.ceil(np.sqrt(len(num_columns['player1']))))
#       4 fig, ax = plt.subplots(1, 1, figsize=(14,8))
#       5 ax.hist(num_columns['player1'], bins)
#
# File c:\Users\gabri\.conda\envs\migrations\Lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File c:\Users\gabri\.conda\envs\migrations\Lib\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'player1'
