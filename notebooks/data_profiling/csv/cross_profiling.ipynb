# %%
import numpy as np
import pandas as pd
from ydata_profiling import ProfileReport
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('../../data/raw/cross.csv',
               encoding='latin-1')
df
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_11244\2733258368.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../../data/raw/cross.csv',
#         match_id         id subtype  event_incident_typefk  elapsed  \
# 0         489042   378863.0   cross                    7.0      7.0
# 1         489042   378921.0   cross                    7.0     14.0
# 2         489042   378960.0   cross                  329.0     19.0
# 3         489042   378970.0   cross                    7.0     19.0
# 4         489042   378978.0   cross                    7.0     20.0
# ...          ...        ...     ...                    ...      ...
# 527094   2030171        NaN     NaN                    NaN      NaN
# 527095   2030171        NaN     NaN                    NaN      NaN
# 527096   2030171  4941100.0   cross                    7.0     87.0
# 527097   2030171        NaN     NaN                    NaN      NaN
# 527098   2030171        NaN     NaN                    NaN      NaN
#
#         elapsed_plus  del  coordinates    type  spectators goal_type  player1  \
# 0                NaN  NaN          NaN   cross         NaN       NaN  30829.0
# 1                NaN  NaN          NaN   cross         NaN       NaN  24148.0
# 2                NaN  NaN          NaN  corner         NaN       NaN  38807.0
# 3                NaN  NaN          NaN   cross         NaN       NaN  30929.0
# 4                NaN  NaN          NaN   cross         NaN       NaN  24148.0
# ...              ...  ...          ...     ...         ...       ...      ...
# 527094           NaN  NaN          NaN     NaN         NaN       NaN      NaN
# 527095           NaN  NaN          NaN     NaN         NaN       NaN      NaN
# 527096           NaN  NaN        614.0   cross         NaN       NaN  40220.0
# 527097           NaN  NaN          NaN     NaN         NaN       NaN      NaN
# 527098           NaN  NaN          NaN     NaN         NaN       NaN      NaN
#
#            team
# 0       10260.0
# 1       10260.0
# 2       10261.0
# 3       10261.0
# 4       10260.0
# ...         ...
# 527094      NaN
# 527095      NaN
# 527096   8370.0
# 527097      NaN
# 527098      NaN
#
# [527099 rows x 13 columns]

# %%
df.dtypes
# Out:
# match_id                   int64
# id                       float64
# subtype                   object
# event_incident_typefk    float64
# elapsed                  float64
# elapsed_plus             float64
# del                      float64
# coordinates              float64
# type                      object
# spectators               float64
# goal_type                 object
# player1                  float64
# team                     float64
# dtype: object

# %%
pd.set_option('display.float_format',lambda x: '%.2f' % x)

# %%
df.describe()
# Out:
#         match_id         id  event_incident_typefk   elapsed  elapsed_plus  \
# count  527099.00  284775.00              284775.00 284775.00      16119.00
# mean  1589101.93 2905714.82                 191.26     47.28          2.42
# std    495527.13 1715310.43                 288.65     26.33          1.40
# min    489042.00  375536.00                   7.00      0.00          1.00
# 25%   1229184.00 1299964.50                   7.00     25.00          1.00
# 50%   1778103.00 2712135.00                   7.00     47.00          2.00
# 75%   1989802.00 4462414.50                 329.00     70.00          3.00
# max   2118418.00 5697209.00                 776.00     90.00         14.00
#
#          del  coordinates  spectators   player1      team
# count 178.00    121162.00        1.00 271419.00 284594.00
# mean    1.00      1785.59    27131.00 104367.60   9456.03
# std     0.00      1731.55         NaN 119478.95   8240.47
# min     1.00        11.00    27131.00   2625.00   1601.00
# 25%     1.00       413.00    27131.00  30843.00   8535.00
# 50%     1.00       660.00    27131.00  39854.00   8661.00
# 75%     1.00      3968.00    27131.00 155913.00   9876.00
# max     1.00      4569.00    27131.00 750435.00 208931.00

# %%
simple_profile = df.describe(include='all')
simple_profile
# Out:
#          match_id         id subtype  event_incident_typefk   elapsed  \
# count   527099.00  284775.00  284775              284775.00 284775.00
# unique        NaN        NaN       1                    NaN       NaN
# top           NaN        NaN   cross                    NaN       NaN
# freq          NaN        NaN  284775                    NaN       NaN
# mean   1589101.93 2905714.82     NaN                 191.26     47.28
# std     495527.13 1715310.43     NaN                 288.65     26.33
# min     489042.00  375536.00     NaN                   7.00      0.00
# 25%    1229184.00 1299964.50     NaN                   7.00     25.00
# 50%    1778103.00 2712135.00     NaN                   7.00     47.00
# 75%    1989802.00 4462414.50     NaN                 329.00     70.00
# max    2118418.00 5697209.00     NaN                 776.00     90.00
#
#         elapsed_plus    del  coordinates    type  spectators goal_type  \
# count       16119.00 178.00    121162.00  284775        1.00         1
# unique           NaN    NaN          NaN       3         NaN         1
# top              NaN    NaN          NaN   cross         NaN         n
# freq             NaN    NaN          NaN  234532         NaN         1
# mean            2.42   1.00      1785.59     NaN    27131.00       NaN
# std             1.40   0.00      1731.55     NaN         NaN       NaN
# min             1.00   1.00        11.00     NaN    27131.00       NaN
# 25%             1.00   1.00       413.00     NaN    27131.00       NaN
# 50%             2.00   1.00       660.00     NaN    27131.00       NaN
# 75%             3.00   1.00      3968.00     NaN    27131.00       NaN
# max            14.00   1.00      4569.00     NaN    27131.00       NaN
#
#          player1      team
# count  271419.00 284594.00
# unique       NaN       NaN
# top          NaN       NaN
# freq         NaN       NaN
# mean   104367.60   9456.03
# std    119478.95   8240.47
# min      2625.00   1601.00
# 25%     30843.00   8535.00
# 50%     39854.00   8661.00
# 75%    155913.00   9876.00
# max    750435.00 208931.00

# %%
profile = ProfileReport(df, title="Export Data Profiling Report")

# %%
profile.to_widgets()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…

# %%
def get_basic_profile(dataframe):
    quantile_range = 0.5
    results = {}
    
    for column in dataframe.columns:
        count = df[column].count()
        nans = df[column].isna().sum()
        min = df[column].min()
        max = df[column].max()
        median = df[column].median()
        std = df[column].std()
        kurt = df[column].kurt()
        skew = df[column].skew()
        quant = df[column].quantile(q=quantile_range)
        
        results[column] = {'count': count,
                            'count_na': nans,
                            'min':min,
                            'max':max,
                            'median':median,
                            'std':std,
                            'kurt':kurt,
                            'skew':skew,
                            'quant {quantile_range}':quant}
 
    return results

# %%
num_columns = df.select_dtypes(include=['int64','float64'])
basic_profile = get_basic_profile(num_columns)
basic_profile
# Out:
# {'match_id': {'count': 527099,
#   'count_na': 0,
#   'min': 489042,
#   'max': 2118418,
#   'median': 1778103.0,
#   'std': 495527.1336878539,
#   'kurt': -0.5078091827207714,
#   'skew': -0.9788509138073862,
#   'quant {quantile_range}': 1778103.0},
#  'id': {'count': 284775,
#   'count_na': 242324,
#   'min': 375536.0,
#   'max': 5697209.0,
#   'median': 2712135.0,
#   'std': 1715310.42617625,
#   'kurt': -1.5148433425643753,
#   'skew': 0.08795839903166477,
#   'quant {quantile_range}': 2712135.0},
#  'event_incident_typefk': {'count': 284775,
#   'count_na': 242324,
#   'min': 7.0,
#   'max': 776.0,
#   'median': 7.0,
#   'std': 288.65437063822384,
#   'kurt': -0.0586064597067093,
#   'skew': 1.255888900558814,
#   'quant {quantile_range}': 7.0},
#  'elapsed': {'count': 284775,
#   'count_na': 242324,
#   'min': 0.0,
#   'max': 90.0,
#   'median': 47.0,
#   'std': 26.33233844534835,
#   'kurt': -1.1739063186222443,
#   'skew': 0.003420378127182033,
#   'quant {quantile_range}': 47.0},
#  'elapsed_plus': {'count': 16119,
#   'count_na': 510980,
#   'min': 1.0,
#   'max': 14.0,
#   'median': 2.0,
#   'std': 1.403506641978959,
#   'kurt': 1.946800560955655,
#   'skew': 1.1271957838890154,
#   'quant {quantile_range}': 2.0},
#  'del': {'count': 178,
#   'count_na': 526921,
#   'min': 1.0,
#   'max': 1.0,
#   'median': 1.0,
#   'std': 0.0,
#   'kurt': 0,
#   'skew': 0,
#   'quant {quantile_range}': 1.0},
#  'coordinates': {'count': 121162,
#   'count_na': 405937,
#   'min': 11.0,
#   'max': 4569.0,
#   'median': 660.0,
#   'std': 1731.5467567333544,
#   'kurt': -1.591964455310711,
#   'skew': 0.5224371159834619,
#   'quant {quantile_range}': 660.0},
#  'spectators': {'count': 1,
#   'count_na': 527098,
#   'min': 27131.0,
#   'max': 27131.0,
#   'median': 27131.0,
#   'std': nan,
#   'kurt': nan,
#   'skew': nan,
#   'quant {quantile_range}': 27131.0},
#  'player1': {'count': 271419,
#   'count_na': 255680,
#   'min': 2625.0,
#   'max': 750435.0,
#   'median': 39854.0,
#   'std': 119478.95351548243,
#   'kurt': 4.433429152179241,
#   'skew': 2.0682082732065847,
#   'quant {quantile_range}': 39854.0},
#  'team': {'count': 284594,
#   'count_na': 242505,
#   'min': 1601.0,
#   'max': 208931.0,
#   'median': 8661.0,
#   'std': 8240.474305416936,
#   'kurt': 576.1240405578841,
#   'skew': 23.921798814246912,
#   'quant {quantile_range}': 8661.0}}

# %%
# square root choice
bins = int(np.ceil(np.sqrt(len(num_columns['team']))))
 
fig, ax = plt.subplots(1, 1, figsize=(14,8))
ax.hist(num_columns['team'], bins)
 
ax.ticklabel_format(useOffset=False, style='plain')
ax.set_xlabel('Value USD')
ax.set_ylabel('Count')
ax.set_title(r'Histogram of exports in USD')
# plt.savefig("mygraph.jpg")
# Out:
# Text(0.5, 1.0, 'Histogram of exports in USD')
