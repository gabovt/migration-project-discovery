# %%
import numpy as np
import pandas as pd
from ydata_profiling import ProfileReport
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('../../data/raw/shoton.csv',
               encoding='latin-1')
df
# Out:
# C:\Users\gabri\AppData\Local\Temp\ipykernel_12864\633759939.py:1: DtypeWarning: Columns (8,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../../data/raw/shoton.csv',
#         match_id         id       subtype  event_incident_typefk  elapsed  \
# 0         489042   378828.0  blocked_shot                   61.0      3.0
# 1         489042   378866.0        header                  154.0      7.0
# 2         489042   378922.0          shot                  153.0     14.0
# 3         489042   378923.0          shot                  153.0     14.0
# 4         489042   378951.0      distance                  137.0     17.0
# ...          ...        ...           ...                    ...      ...
# 179714   2030171        NaN           NaN                    NaN      NaN
# 179715   2030171        NaN           NaN                    NaN      NaN
# 179716   2030171  4941144.0  blocked_shot                   61.0     90.0
# 179717   2030171        NaN           NaN                    NaN      NaN
# 179718   2030171        NaN           NaN                    NaN      NaN
#
#         elapsed_plus  del  coordinates goal_type card_type   player1     team
# 0                NaN  NaN          NaN       NaN       NaN   24154.0  10260.0
# 1                NaN  NaN          NaN       NaN       NaN   24157.0  10260.0
# 2                NaN  NaN          NaN       NaN       NaN   30829.0  10260.0
# 3                NaN  NaN          NaN       NaN       NaN   30373.0  10260.0
# 4                NaN  NaN          NaN       NaN       NaN   30373.0  10260.0
# ...              ...  ...          ...       ...       ...       ...      ...
# 179714           NaN  NaN          NaN       NaN       NaN       NaN      NaN
# 179715           NaN  NaN          NaN       NaN       NaN       NaN      NaN
# 179716           2.0  NaN       3362.0       NaN       NaN  452243.0   8558.0
# 179717           NaN  NaN          NaN       NaN       NaN       NaN      NaN
# 179718           NaN  NaN          NaN       NaN       NaN       NaN      NaN
#
# [179719 rows x 12 columns]

# %%
df.dtypes
# Out:
# match_id                   int64
# id                       float64
# subtype                   object
# event_incident_typefk    float64
# elapsed                  float64
# elapsed_plus             float64
# del                      float64
# coordinates              float64
# goal_type                 object
# card_type                 object
# player1                  float64
# team                     float64
# dtype: object

# %%
pd.set_option('display.float_format',lambda x: '%.2f' % x)

# %%
df.describe()
# Out:
#         match_id         id  event_incident_typefk  elapsed  elapsed_plus  \
# count  179719.00   93755.00               93755.00 93755.00       5968.00
# mean  1607796.85 2957008.83                 176.98    49.15          2.45
# std    488068.38 1726226.29                 161.14    26.26          1.45
# min    489042.00  375556.00                   8.00     1.00        -10.00
# 25%   1229388.50 1314502.00                  61.00    27.00          1.00
# 50%   1778191.00 3043736.00                 137.00    50.00          2.00
# 75%   1989802.50 4513349.50                 153.00    72.00          3.00
# max   2118418.00 5623584.00                 876.00    90.00         13.00
#
#         del  coordinates   player1      team
# count 70.00     42982.00  92802.00  93684.00
# mean   1.00      1746.59 105146.59   9469.39
# std    0.00      1126.95 119874.94   8592.13
# min    1.00        25.00   2625.00   1601.00
# 25%    1.00       326.00  30872.00   8535.00
# 50%    1.00      1865.00  40055.00   8659.00
# 75%    1.00      2666.00 156008.00   9875.00
# max    1.00      4455.00 749661.00 208931.00

# %%
simple_profile = df.describe(include='all')
simple_profile
# Out:
#          match_id         id       subtype  event_incident_typefk  elapsed  \
# count   179719.00   93755.00         93737               93755.00 93755.00
# unique        NaN        NaN            16                    NaN      NaN
# top           NaN        NaN  blocked_shot                    NaN      NaN
# freq          NaN        NaN         31635                    NaN      NaN
# mean   1607796.85 2957008.83           NaN                 176.98    49.15
# std     488068.38 1726226.29           NaN                 161.14    26.26
# min     489042.00  375556.00           NaN                   8.00     1.00
# 25%    1229388.50 1314502.00           NaN                  61.00    27.00
# 50%    1778191.00 3043736.00           NaN                 137.00    50.00
# 75%    1989802.50 4513349.50           NaN                 153.00    72.00
# max    2118418.00 5623584.00           NaN                 876.00    90.00
#
#         elapsed_plus   del  coordinates goal_type card_type   player1  \
# count        5968.00 70.00     42982.00         2         1  92802.00
# unique           NaN   NaN          NaN         2         1       NaN
# top              NaN   NaN          NaN        dg         y       NaN
# freq             NaN   NaN          NaN         1         1       NaN
# mean            2.45  1.00      1746.59       NaN       NaN 105146.59
# std             1.45  0.00      1126.95       NaN       NaN 119874.94
# min           -10.00  1.00        25.00       NaN       NaN   2625.00
# 25%             1.00  1.00       326.00       NaN       NaN  30872.00
# 50%             2.00  1.00      1865.00       NaN       NaN  40055.00
# 75%             3.00  1.00      2666.00       NaN       NaN 156008.00
# max            13.00  1.00      4455.00       NaN       NaN 749661.00
#
#             team
# count   93684.00
# unique       NaN
# top          NaN
# freq         NaN
# mean     9469.39
# std      8592.13
# min      1601.00
# 25%      8535.00
# 50%      8659.00
# 75%      9875.00
# max    208931.00

# %%
profile = ProfileReport(df, title="Export Data Profiling Report")

# %%
profile.to_widgets()
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render widgets:   0%|          | 0/1 [00:00<?, ?it/s]
# VBox(children=(Tab(children=(Tab(children=(GridBox(children=(VBox(children=(GridspecLayout(children=(HTML(valu…

# %%
def get_basic_profile(dataframe):
    quantile_range = 0.5
    results = {}
    
    for column in dataframe.columns:
        count = df[column].count()
        nans = df[column].isna().sum()
        min = df[column].min()
        max = df[column].max()
        median = df[column].median()
        std = df[column].std()
        kurt = df[column].kurt()
        skew = df[column].skew()
        quant = df[column].quantile(q=quantile_range)
        
        results[column] = {'count': count,
                            'count_na': nans,
                            'min':min,
                            'max':max,
                            'median':median,
                            'std':std,
                            'kurt':kurt,
                            'skew':skew,
                            'quant {quantile_range}':quant}
 
    return results

# %%
num_columns = df.select_dtypes(include=['int64','float64'])
basic_profile = get_basic_profile(num_columns)
basic_profile
# Out:
# {'match_id': {'count': 179719,
#   'count_na': 0,
#   'min': 489042,
#   'max': 2118418,
#   'median': 1778191.0,
#   'std': 488068.3799481937,
#   'kurt': -0.31156244859382465,
#   'skew': -1.065806876280843,
#   'quant {quantile_range}': 1778191.0},
#  'id': {'count': 93755,
#   'count_na': 85964,
#   'min': 375556.0,
#   'max': 5623584.0,
#   'median': 3043736.0,
#   'std': 1726226.285897606,
#   'kurt': -1.5399539302875298,
#   'skew': 0.029322813791246776,
#   'quant {quantile_range}': 3043736.0},
#  'event_incident_typefk': {'count': 93755,
#   'count_na': 85964,
#   'min': 8.0,
#   'max': 876.0,
#   'median': 137.0,
#   'std': 161.1355050447382,
#   'kurt': 3.8888304228366457,
#   'skew': 2.08416388649135,
#   'quant {quantile_range}': 137.0},
#  'elapsed': {'count': 93755,
#   'count_na': 85964,
#   'min': 1.0,
#   'max': 90.0,
#   'median': 50.0,
#   'std': 26.26066367559024,
#   'kurt': -1.178428119278098,
#   'skew': -0.06948846673394556,
#   'quant {quantile_range}': 50.0},
#  'elapsed_plus': {'count': 5968,
#   'count_na': 173751,
#   'min': -10.0,
#   'max': 13.0,
#   'median': 2.0,
#   'std': 1.4483112974741366,
#   'kurt': 2.873644376359656,
#   'skew': 1.0509859967958017,
#   'quant {quantile_range}': 2.0},
#  'del': {'count': 70,
#   'count_na': 179649,
#   'min': 1.0,
#   'max': 1.0,
#   'median': 1.0,
#   'std': 0.0,
#   'kurt': 0,
#   'skew': 0,
#   'quant {quantile_range}': 1.0},
#  'coordinates': {'count': 42982,
#   'count_na': 136737,
#   'min': 25.0,
#   'max': 4455.0,
#   'median': 1865.0,
#   'std': 1126.9461084492216,
#   'kurt': -1.267835284780466,
#   'skew': -0.11775803529900497,
#   'quant {quantile_range}': 1865.0},
#  'player1': {'count': 92802,
#   'count_na': 86917,
#   'min': 2625.0,
#   'max': 749661.0,
#   'median': 40055.0,
#   'std': 119874.93813738595,
#   'kurt': 4.465588887621095,
#   'skew': 2.0714923039247553,
#   'quant {quantile_range}': 40055.0},
#  'team': {'count': 93684,
#   'count_na': 86035,
#   'min': 1601.0,
#   'max': 208931.0,
#   'median': 8659.0,
#   'std': 8592.127831024613,
#   'kurt': 530.249278325197,
#   'skew': 22.96796765324291,
#   'quant {quantile_range}': 8659.0}}

# %%
# square root choice
bins = int(np.ceil(np.sqrt(len(num_columns['player1']))))
 
fig, ax = plt.subplots(1, 1, figsize=(14,8))
ax.hist(num_columns['player1'], bins)
 
ax.ticklabel_format(useOffset=False, style='plain')
ax.set_xlabel('player')
ax.set_ylabel('Count')
ax.set_title(r'Histogram of shotoff per player')
# plt.savefig("mygraph.jpg")
# Out:
# Text(0.5, 1.0, 'Histogram of shotoff per player')
